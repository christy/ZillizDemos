# %% [markdown]
# # Load data into a vector database
#
# Load chunked context data embedding vectors into an indexed database.
#
# - **Data**: ReadtheDocs documentation pages.
# - **Vector database**: FAISS and Milvus
#
# Demo in progress...

# %%
# Import common libraries.
import time, os
import numpy as np

# Import langchain.
#!pip install langchain 
from langchain.document_loaders import ReadTheDocsLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter

# %% [markdown]
# We need to first download the Milvus documentation to a local directory:

# %%
# Uncomment to download readthedocs page locally.

# DOCS_PAGE="https://pymilvus.readthedocs.io/en/latest/"
# !echo $DOCS_PAGE

# # Specify encoding to handle non-unicode characters in documentation.
# !wget -r -A.html -P rtdocs --header="Accept-Charset: UTF-8" $DOCS_PAGE
# Out:
# https://pymilvus.readthedocs.io/en/latest/
# --2023-09-21 19:38:11--  https://pymilvus.readthedocs.io/en/latest/
# Resolving pymilvus.readthedocs.io (pymilvus.readthedocs.io)... 104.17.33.82, 104.17.32.82
# Connecting to pymilvus.readthedocs.io (pymilvus.readthedocs.io)|104.17.33.82|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/pymilvus.readthedocs.io/en/latest/index.html’
#
# pymilvus.readthedoc     [ <=>                ]  10.60K  --.-KB/s    in 0s
#
# 2023-09-21 19:38:12 (98.6 MB/s) - ‘rtdocs/pymilvus.readthedocs.io/en/latest/index.html’ saved [10857]
#
# Loading robots.txt; please ignore errors.
# --2023-09-21 19:38:12--  https://pymilvus.readthedocs.io/robots.txt
# Reusing existing connection to pymilvus.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 146 [text/plain]
# Saving to: ‘rtdocs/pymilvus.readthedocs.io/robots.txt.tmp’
#
# pymilvus.readthedoc 100%[===================>]     146  --.-KB/s    in 0s
#
# 2023-09-21 19:38:12 (27.8 MB/s) - ‘rtdocs/pymilvus.readthedocs.io/robots.txt.tmp’ saved [146/146]
#
# Removing rtdocs/pymilvus.readthedocs.io/robots.txt.tmp.
# --2023-09-21 19:38:12--  https://pymilvus.readthedocs.io/en/latest/about.html
# Reusing existing connection to pymilvus.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/pymilvus.readthedocs.io/en/latest/about.html’
#
# pymilvus.readthedoc     [ <=>                ]   9.52K  --.-KB/s    in 0s
#
# 2023-09-21 19:38:12 (44.5 MB/s) - ‘rtdocs/pymilvus.readthedocs.io/en/latest/about.html’ saved [9753]
#
# --2023-09-21 19:38:12--  https://pymilvus.readthedocs.io/en/latest/genindex.html
# Reusing existing connection to pymilvus.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/pymilvus.readthedocs.io/en/latest/genindex.html’
#
# pymilvus.readthedoc     [ <=>                ]  15.81K  --.-KB/s    in 0.002s
#
# 2023-09-21 19:38:13 (8.31 MB/s) - ‘rtdocs/pymilvus.readthedocs.io/en/latest/genindex.html’ saved [16192]
#
# --2023-09-21 19:38:13--  https://pymilvus.readthedocs.io/en/latest/search.html
# Reusing existing connection to pymilvus.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/pymilvus.readthedocs.io/en/latest/search.html’
#
# pymilvus.readthedoc     [ <=>                ]   8.46K  --.-KB/s    in 0.002s
#
# 2023-09-21 19:38:13 (3.42 MB/s) - ‘rtdocs/pymilvus.readthedocs.io/en/latest/search.html’ saved [8667]
#
# --2023-09-21 19:38:13--  https://pymilvus.readthedocs.io/en/latest/install.html
# Reusing existing connection to pymilvus.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/pymilvus.readthedocs.io/en/latest/install.html’
#
# pymilvus.readthedoc     [ <=>                ]  13.51K  --.-KB/s    in 0.002s
#
# 2023-09-21 19:38:13 (8.17 MB/s) - ‘rtdocs/pymilvus.readthedocs.io/en/latest/install.html’ saved [13838]
#
# --2023-09-21 19:38:13--  https://pymilvus.readthedocs.io/en/latest/tutorial.html
# Reusing existing connection to pymilvus.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/pymilvus.readthedocs.io/en/latest/tutorial.html’
#
# pymilvus.readthedoc     [ <=>                ]  37.65K  --.-KB/s    in 0.001s
#
# 2023-09-21 19:38:13 (24.7 MB/s) - ‘rtdocs/pymilvus.readthedocs.io/en/latest/tutorial.html’ saved [38551]
#
# --2023-09-21 19:38:13--  https://pymilvus.readthedocs.io/en/latest/api.html
# Reusing existing connection to pymilvus.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/pymilvus.readthedocs.io/en/latest/api.html’
#
# pymilvus.readthedoc     [ <=>                ]  56.97K  --.-KB/s    in 0.001s
#
# 2023-09-21 19:38:14 (59.1 MB/s) - ‘rtdocs/pymilvus.readthedocs.io/en/latest/api.html’ saved [58335]
#
# --2023-09-21 19:38:14--  https://pymilvus.readthedocs.io/en/latest/param.html
# Reusing existing connection to pymilvus.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/pymilvus.readthedocs.io/en/latest/param.html’
#
# pymilvus.readthedoc     [ <=>                ]  34.34K  --.-KB/s    in 0.002s
#
# 2023-09-21 19:38:14 (16.7 MB/s) - ‘rtdocs/pymilvus.readthedocs.io/en/latest/param.html’ saved [35167]
#
# --2023-09-21 19:38:14--  https://pymilvus.readthedocs.io/en/latest/results.html
# Reusing existing connection to pymilvus.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/pymilvus.readthedocs.io/en/latest/results.html’
#
# pymilvus.readthedoc     [ <=>                ]  13.14K  --.-KB/s    in 0s
#
# 2023-09-21 19:38:14 (1.79 GB/s) - ‘rtdocs/pymilvus.readthedocs.io/en/latest/results.html’ saved [13460]
#
# --2023-09-21 19:38:14--  https://pymilvus.readthedocs.io/en/latest/changes.html
# Reusing existing connection to pymilvus.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/pymilvus.readthedocs.io/en/latest/changes.html’
#
# pymilvus.readthedoc     [ <=>                ]   8.99K  --.-KB/s    in 0s
#
# 2023-09-21 19:38:15 (2.86 GB/s) - ‘rtdocs/pymilvus.readthedocs.io/en/latest/changes.html’ saved [9205]
#
# --2023-09-21 19:38:15--  https://pymilvus.readthedocs.io/en/latest/faq.html
# Reusing existing connection to pymilvus.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/pymilvus.readthedocs.io/en/latest/faq.html’
#
# pymilvus.readthedoc     [ <=>                ]  10.53K  --.-KB/s    in 0s
#
# 2023-09-21 19:38:15 (2.51 GB/s) - ‘rtdocs/pymilvus.readthedocs.io/en/latest/faq.html’ saved [10785]
#
# --2023-09-21 19:38:15--  https://pymilvus.readthedocs.io/en/latest/contribute.html
# Reusing existing connection to pymilvus.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/pymilvus.readthedocs.io/en/latest/contribute.html’
#
# pymilvus.readthedoc     [ <=>                ]  14.37K  --.-KB/s    in 0s
#
# 2023-09-21 19:38:15 (2.28 GB/s) - ‘rtdocs/pymilvus.readthedocs.io/en/latest/contribute.html’ saved [14713]
#
# --2023-09-21 19:38:15--  https://pymilvus.readthedocs.io/en/1.1/
# Reusing existing connection to pymilvus.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/pymilvus.readthedocs.io/en/1.1/index.html’
#
# pymilvus.readthedoc     [ <=>                ]  10.58K  --.-KB/s    in 0s
#
# 2023-09-21 19:38:16 (10.1 GB/s) - ‘rtdocs/pymilvus.readthedocs.io/en/1.1/index.html’ saved [10839]
#
# --2023-09-21 19:38:16--  https://pymilvus.readthedocs.io/en/1.0/
# Reusing existing connection to pymilvus.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/pymilvus.readthedocs.io/en/1.0/index.html’
#
# pymilvus.readthedoc     [ <=>                ]  10.59K  --.-KB/s    in 0s
#
# 2023-09-21 19:38:16 (1.01 GB/s) - ‘rtdocs/pymilvus.readthedocs.io/en/1.0/index.html’ saved [10845]
#
# --2023-09-21 19:38:16--  https://pymilvus.readthedocs.io/_/downloads/en/latest/pdf/
# Reusing existing connection to pymilvus.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 229768 (224K) [application/pdf]
# Saving to: ‘rtdocs/pymilvus.readthedocs.io/_/downloads/en/latest/pdf/index.html’
#
# pymilvus.readthedoc 100%[===================>] 224.38K  --.-KB/s    in 0.01s
#
# 2023-09-21 19:38:16 (19.1 MB/s) - ‘rtdocs/pymilvus.readthedocs.io/_/downloads/en/latest/pdf/index.html’ saved [229768/229768]
#
# --2023-09-21 19:38:16--  https://pymilvus.readthedocs.io/_/downloads/en/latest/htmlzip/
# Reusing existing connection to pymilvus.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 9998090 (9.5M) [application/zip]
# Saving to: ‘rtdocs/pymilvus.readthedocs.io/_/downloads/en/latest/htmlzip/index.html’
#
# pymilvus.readthedoc 100%[===================>]   9.53M  9.53MB/s    in 1.0s
#
# 2023-09-21 19:38:18 (9.53 MB/s) - ‘rtdocs/pymilvus.readthedocs.io/_/downloads/en/latest/htmlzip/index.html’ saved [9998090/9998090]
#
# --2023-09-21 19:38:18--  https://pymilvus.readthedocs.io/_/downloads/en/latest/epub/
# Reusing existing connection to pymilvus.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 53948 (53K) [application/epub+zip]
# Saving to: ‘rtdocs/pymilvus.readthedocs.io/_/downloads/en/latest/epub/index.html’
#
# pymilvus.readthedoc 100%[===================>]  52.68K  --.-KB/s    in 0.002s
#
# 2023-09-21 19:38:18 (32.6 MB/s) - ‘rtdocs/pymilvus.readthedocs.io/_/downloads/en/latest/epub/index.html’ saved [53948/53948]
#
# --2023-09-21 19:38:18--  https://pymilvus.readthedocs.io/en/latest/index.html
# Reusing existing connection to pymilvus.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/pymilvus.readthedocs.io/en/latest/index.html’
#
# pymilvus.readthedoc     [ <=>                ]  10.60K  --.-KB/s    in 0s
#
# 2023-09-21 19:38:18 (2.53 GB/s) - ‘rtdocs/pymilvus.readthedocs.io/en/latest/index.html’ saved [10857]
#
# --2023-09-21 19:38:18--  https://pymilvus.readthedocs.io/en/1.1/install.html
# Reusing existing connection to pymilvus.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/pymilvus.readthedocs.io/en/1.1/install.html’
#
# pymilvus.readthedoc     [ <=>                ]  13.50K  --.-KB/s    in 0s
#
# 2023-09-21 19:38:18 (1.61 GB/s) - ‘rtdocs/pymilvus.readthedocs.io/en/1.1/install.html’ saved [13820]
#
# --2023-09-21 19:38:18--  https://pymilvus.readthedocs.io/en/1.1/param.html
# Reusing existing connection to pymilvus.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/pymilvus.readthedocs.io/en/1.1/param.html’
#
# pymilvus.readthedoc     [ <=>                ]  34.33K  --.-KB/s    in 0s
#
# 2023-09-21 19:38:19 (124 MB/s) - ‘rtdocs/pymilvus.readthedocs.io/en/1.1/param.html’ saved [35149]
#
# --2023-09-21 19:38:19--  https://pymilvus.readthedocs.io/en/1.1/results.html
# Reusing existing connection to pymilvus.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/pymilvus.readthedocs.io/en/1.1/results.html’
#
# pymilvus.readthedoc     [ <=>                ]  13.13K  --.-KB/s    in 0s
#
# 2023-09-21 19:38:19 (3.13 GB/s) - ‘rtdocs/pymilvus.readthedocs.io/en/1.1/results.html’ saved [13442]
#
# --2023-09-21 19:38:19--  https://pymilvus.readthedocs.io/en/latest/_modules/milvus/client/stub.html
# Reusing existing connection to pymilvus.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/pymilvus.readthedocs.io/en/latest/_modules/milvus/client/stub.html’
#
# pymilvus.readthedoc     [ <=>                ] 115.71K  --.-KB/s    in 0.006s
#
# 2023-09-21 19:38:19 (18.5 MB/s) - ‘rtdocs/pymilvus.readthedocs.io/en/latest/_modules/milvus/client/stub.html’ saved [118486]
#
# --2023-09-21 19:38:19--  https://pymilvus.readthedocs.io/en/latest/_modules/milvus/client/types.html
# Reusing existing connection to pymilvus.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/pymilvus.readthedocs.io/en/latest/_modules/milvus/client/types.html’
#
# pymilvus.readthedoc     [ <=>                ]  21.83K  --.-KB/s    in 0s
#
# 2023-09-21 19:38:20 (118 MB/s) - ‘rtdocs/pymilvus.readthedocs.io/en/latest/_modules/milvus/client/types.html’ saved [22359]
#
# --2023-09-21 19:38:20--  https://pymilvus.readthedocs.io/en/1.1/about.html
# Reusing existing connection to pymilvus.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/pymilvus.readthedocs.io/en/1.1/about.html’
#
# pymilvus.readthedoc     [ <=>                ]   9.51K  --.-KB/s    in 0s
#
# 2023-09-21 19:38:20 (1.81 GB/s) - ‘rtdocs/pymilvus.readthedocs.io/en/1.1/about.html’ saved [9735]
#
# --2023-09-21 19:38:20--  https://pymilvus.readthedocs.io/en/1.1/genindex.html
# Reusing existing connection to pymilvus.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/pymilvus.readthedocs.io/en/1.1/genindex.html’
#
# pymilvus.readthedoc     [ <=>                ]  15.79K  --.-KB/s    in 0s
#
# 2023-09-21 19:38:20 (93.5 MB/s) - ‘rtdocs/pymilvus.readthedocs.io/en/1.1/genindex.html’ saved [16174]
#
# --2023-09-21 19:38:20--  https://pymilvus.readthedocs.io/en/1.1/search.html
# Reusing existing connection to pymilvus.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/pymilvus.readthedocs.io/en/1.1/search.html’
#
# pymilvus.readthedoc     [ <=>                ]   8.45K  --.-KB/s    in 0s
#
# 2023-09-21 19:38:20 (1.34 GB/s) - ‘rtdocs/pymilvus.readthedocs.io/en/1.1/search.html’ saved [8649]
#
# --2023-09-21 19:38:20--  https://pymilvus.readthedocs.io/en/1.1/tutorial.html
# Reusing existing connection to pymilvus.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/pymilvus.readthedocs.io/en/1.1/tutorial.html’
#
# pymilvus.readthedoc     [ <=>                ]  37.63K  --.-KB/s    in 0.002s
#
# 2023-09-21 19:38:21 (20.8 MB/s) - ‘rtdocs/pymilvus.readthedocs.io/en/1.1/tutorial.html’ saved [38533]
#
# --2023-09-21 19:38:21--  https://pymilvus.readthedocs.io/en/1.1/api.html
# Reusing existing connection to pymilvus.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/pymilvus.readthedocs.io/en/1.1/api.html’
#
# pymilvus.readthedoc     [ <=>                ]  56.95K  --.-KB/s    in 0.003s
#
# 2023-09-21 19:38:21 (16.7 MB/s) - ‘rtdocs/pymilvus.readthedocs.io/en/1.1/api.html’ saved [58317]
#
# --2023-09-21 19:38:21--  https://pymilvus.readthedocs.io/en/1.1/changes.html
# Reusing existing connection to pymilvus.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/pymilvus.readthedocs.io/en/1.1/changes.html’
#
# pymilvus.readthedoc     [ <=>                ]   8.97K  --.-KB/s    in 0s
#
# 2023-09-21 19:38:21 (1.43 GB/s) - ‘rtdocs/pymilvus.readthedocs.io/en/1.1/changes.html’ saved [9187]
#
# --2023-09-21 19:38:21--  https://pymilvus.readthedocs.io/en/1.1/faq.html
# Reusing existing connection to pymilvus.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/pymilvus.readthedocs.io/en/1.1/faq.html’
#
# pymilvus.readthedoc     [ <=>                ]  10.51K  --.-KB/s    in 0s
#
# 2023-09-21 19:38:22 (2.01 GB/s) - ‘rtdocs/pymilvus.readthedocs.io/en/1.1/faq.html’ saved [10767]
#
# --2023-09-21 19:38:22--  https://pymilvus.readthedocs.io/en/1.1/contribute.html
# Reusing existing connection to pymilvus.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/pymilvus.readthedocs.io/en/1.1/contribute.html’
#
# pymilvus.readthedoc     [ <=>                ]  14.35K  --.-KB/s    in 0s
#
# 2023-09-21 19:38:22 (2.28 GB/s) - ‘rtdocs/pymilvus.readthedocs.io/en/1.1/contribute.html’ saved [14695]
#
# --2023-09-21 19:38:22--  https://pymilvus.readthedocs.io/_/downloads/en/1.1/pdf/
# Reusing existing connection to pymilvus.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 229768 (224K) [application/pdf]
# Saving to: ‘rtdocs/pymilvus.readthedocs.io/_/downloads/en/1.1/pdf/index.html’
#
# pymilvus.readthedoc 100%[===================>] 224.38K  --.-KB/s    in 0.02s
#
# 2023-09-21 19:38:22 (13.3 MB/s) - ‘rtdocs/pymilvus.readthedocs.io/_/downloads/en/1.1/pdf/index.html’ saved [229768/229768]
#
# --2023-09-21 19:38:22--  https://pymilvus.readthedocs.io/_/downloads/en/1.1/htmlzip/
# Reusing existing connection to pymilvus.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 9997697 (9.5M) [application/zip]
# Saving to: ‘rtdocs/pymilvus.readthedocs.io/_/downloads/en/1.1/htmlzip/index.html’
#
# pymilvus.readthedoc 100%[===================>]   9.53M  5.28MB/s    in 1.8s
#
# 2023-09-21 19:38:24 (5.28 MB/s) - ‘rtdocs/pymilvus.readthedocs.io/_/downloads/en/1.1/htmlzip/index.html’ saved [9997697/9997697]
#
# --2023-09-21 19:38:24--  https://pymilvus.readthedocs.io/_/downloads/en/1.1/epub/
# Reusing existing connection to pymilvus.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 53948 (53K) [application/epub+zip]
# Saving to: ‘rtdocs/pymilvus.readthedocs.io/_/downloads/en/1.1/epub/index.html’
#
# pymilvus.readthedoc 100%[===================>]  52.68K  --.-KB/s    in 0.001s
#
# 2023-09-21 19:38:25 (47.2 MB/s) - ‘rtdocs/pymilvus.readthedocs.io/_/downloads/en/1.1/epub/index.html’ saved [53948/53948]
#
# --2023-09-21 19:38:25--  https://pymilvus.readthedocs.io/en/1.0/about.html
# Reusing existing connection to pymilvus.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/pymilvus.readthedocs.io/en/1.0/about.html’
#
# pymilvus.readthedoc     [ <=>                ]   9.51K  --.-KB/s    in 0s
#
# 2023-09-21 19:38:25 (1.30 GB/s) - ‘rtdocs/pymilvus.readthedocs.io/en/1.0/about.html’ saved [9741]
#
# --2023-09-21 19:38:25--  https://pymilvus.readthedocs.io/en/1.0/genindex.html
# Reusing existing connection to pymilvus.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/pymilvus.readthedocs.io/en/1.0/genindex.html’
#
# pymilvus.readthedoc     [ <=>                ]  15.62K  --.-KB/s    in 0s
#
# 2023-09-21 19:38:25 (139 MB/s) - ‘rtdocs/pymilvus.readthedocs.io/en/1.0/genindex.html’ saved [15999]
#
# --2023-09-21 19:38:25--  https://pymilvus.readthedocs.io/en/1.0/search.html
# Reusing existing connection to pymilvus.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/pymilvus.readthedocs.io/en/1.0/search.html’
#
# pymilvus.readthedoc     [ <=>                ]   8.45K  --.-KB/s    in 0s
#
# 2023-09-21 19:38:25 (1.34 GB/s) - ‘rtdocs/pymilvus.readthedocs.io/en/1.0/search.html’ saved [8655]
#
# --2023-09-21 19:38:25--  https://pymilvus.readthedocs.io/en/1.0/install.html
# Reusing existing connection to pymilvus.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/pymilvus.readthedocs.io/en/1.0/install.html’
#
# pymilvus.readthedoc     [ <=>                ]  13.50K  --.-KB/s    in 0s
#
# 2023-09-21 19:38:26 (2.15 GB/s) - ‘rtdocs/pymilvus.readthedocs.io/en/1.0/install.html’ saved [13826]
#
# --2023-09-21 19:38:26--  https://pymilvus.readthedocs.io/en/1.0/tutorial.html
# Reusing existing connection to pymilvus.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/pymilvus.readthedocs.io/en/1.0/tutorial.html’
#
# pymilvus.readthedoc     [ <=>                ]  37.64K  --.-KB/s    in 0.001s
#
# 2023-09-21 19:38:26 (30.8 MB/s) - ‘rtdocs/pymilvus.readthedocs.io/en/1.0/tutorial.html’ saved [38539]
#
# --2023-09-21 19:38:26--  https://pymilvus.readthedocs.io/en/1.0/api.html
# Reusing existing connection to pymilvus.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/pymilvus.readthedocs.io/en/1.0/api.html’
#
# pymilvus.readthedoc     [ <=>                ]  59.46K  --.-KB/s    in 0.001s
#
# 2023-09-21 19:38:26 (38.8 MB/s) - ‘rtdocs/pymilvus.readthedocs.io/en/1.0/api.html’ saved [60891]
#
# --2023-09-21 19:38:26--  https://pymilvus.readthedocs.io/en/1.0/param.html
# Reusing existing connection to pymilvus.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/pymilvus.readthedocs.io/en/1.0/param.html’
#
# pymilvus.readthedoc     [ <=>                ]  34.33K  --.-KB/s    in 0s
#
# 2023-09-21 19:38:27 (74.8 MB/s) - ‘rtdocs/pymilvus.readthedocs.io/en/1.0/param.html’ saved [35155]
#
# --2023-09-21 19:38:27--  https://pymilvus.readthedocs.io/en/1.0/results.html
# Reusing existing connection to pymilvus.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/pymilvus.readthedocs.io/en/1.0/results.html’
#
# pymilvus.readthedoc     [ <=>                ]  13.04K  --.-KB/s    in 0s
#
# 2023-09-21 19:38:27 (1.78 GB/s) - ‘rtdocs/pymilvus.readthedocs.io/en/1.0/results.html’ saved [13354]
#
# --2023-09-21 19:38:27--  https://pymilvus.readthedocs.io/en/1.0/changes.html
# Reusing existing connection to pymilvus.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/pymilvus.readthedocs.io/en/1.0/changes.html’
#
# pymilvus.readthedoc     [ <=>                ]   8.98K  --.-KB/s    in 0s
#
# 2023-09-21 19:38:27 (4.28 GB/s) - ‘rtdocs/pymilvus.readthedocs.io/en/1.0/changes.html’ saved [9193]
#
# --2023-09-21 19:38:27--  https://pymilvus.readthedocs.io/en/1.0/faq.html
# Reusing existing connection to pymilvus.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/pymilvus.readthedocs.io/en/1.0/faq.html’
#
# pymilvus.readthedoc     [ <=>                ]  10.52K  --.-KB/s    in 0s
#
# 2023-09-21 19:38:27 (3.34 GB/s) - ‘rtdocs/pymilvus.readthedocs.io/en/1.0/faq.html’ saved [10773]
#
# --2023-09-21 19:38:27--  https://pymilvus.readthedocs.io/en/1.0/contribute.html
# Reusing existing connection to pymilvus.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/pymilvus.readthedocs.io/en/1.0/contribute.html’
#
# pymilvus.readthedoc     [ <=>                ]  14.36K  --.-KB/s    in 0s
#
# 2023-09-21 19:38:27 (4.56 GB/s) - ‘rtdocs/pymilvus.readthedocs.io/en/1.0/contribute.html’ saved [14701]
#
# --2023-09-21 19:38:27--  https://pymilvus.readthedocs.io/en/stable/
# Reusing existing connection to pymilvus.readthedocs.io:443.
# HTTP request sent, awaiting response... 404 Not Found
# 2023-09-21 19:38:28 ERROR 404: Not Found.
#
# --2023-09-21 19:38:28--  https://pymilvus.readthedocs.io/_/downloads/en/1.0/pdf/
# Reusing existing connection to pymilvus.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 231829 (226K) [application/pdf]
# Saving to: ‘rtdocs/pymilvus.readthedocs.io/_/downloads/en/1.0/pdf/index.html’
#
# pymilvus.readthedoc 100%[===================>] 226.40K  --.-KB/s    in 0.01s
#
# 2023-09-21 19:38:28 (20.9 MB/s) - ‘rtdocs/pymilvus.readthedocs.io/_/downloads/en/1.0/pdf/index.html’ saved [231829/231829]
#
# --2023-09-21 19:38:28--  https://pymilvus.readthedocs.io/_/downloads/en/1.0/htmlzip/
# Reusing existing connection to pymilvus.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 9999728 (9.5M) [application/zip]
# Saving to: ‘rtdocs/pymilvus.readthedocs.io/_/downloads/en/1.0/htmlzip/index.html’
#
# pymilvus.readthedoc 100%[===================>]   9.54M  7.91MB/s    in 1.2s
#
# 2023-09-21 19:38:30 (7.91 MB/s) - ‘rtdocs/pymilvus.readthedocs.io/_/downloads/en/1.0/htmlzip/index.html’ saved [9999728/9999728]
#
# --2023-09-21 19:38:30--  https://pymilvus.readthedocs.io/_/downloads/en/1.0/epub/
# Reusing existing connection to pymilvus.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 54038 (53K) [application/epub+zip]
# Saving to: ‘rtdocs/pymilvus.readthedocs.io/_/downloads/en/1.0/epub/index.html’
#
# pymilvus.readthedoc 100%[===================>]  52.77K  --.-KB/s    in 0.004s
#
# 2023-09-21 19:38:30 (12.3 MB/s) - ‘rtdocs/pymilvus.readthedocs.io/_/downloads/en/1.0/epub/index.html’ saved [54038/54038]
#
# --2023-09-21 19:38:30--  https://pymilvus.readthedocs.io/en/1.1/index.html
# Reusing existing connection to pymilvus.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/pymilvus.readthedocs.io/en/1.1/index.html’
#
# pymilvus.readthedoc     [ <=>                ]  10.58K  --.-KB/s    in 0s
#
# 2023-09-21 19:38:30 (5.05 GB/s) - ‘rtdocs/pymilvus.readthedocs.io/en/1.1/index.html’ saved [10839]
#
# --2023-09-21 19:38:30--  https://pymilvus.readthedocs.io/en/latest/_modules/index.html
# Reusing existing connection to pymilvus.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/pymilvus.readthedocs.io/en/latest/_modules/index.html’
#
# pymilvus.readthedoc     [ <=>                ]   8.12K  --.-KB/s    in 0s
#
# 2023-09-21 19:38:30 (1.55 GB/s) - ‘rtdocs/pymilvus.readthedocs.io/en/latest/_modules/index.html’ saved [8316]
#
# --2023-09-21 19:38:30--  https://pymilvus.readthedocs.io/en/1.1/_modules/milvus/client/stub.html
# Reusing existing connection to pymilvus.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/pymilvus.readthedocs.io/en/1.1/_modules/milvus/client/stub.html’
#
# pymilvus.readthedoc     [ <=>                ] 115.69K  --.-KB/s    in 0.01s
#
# 2023-09-21 19:38:31 (11.7 MB/s) - ‘rtdocs/pymilvus.readthedocs.io/en/1.1/_modules/milvus/client/stub.html’ saved [118468]
#
# --2023-09-21 19:38:31--  https://pymilvus.readthedocs.io/en/1.1/_modules/milvus/client/types.html
# Reusing existing connection to pymilvus.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/pymilvus.readthedocs.io/en/1.1/_modules/milvus/client/types.html’
#
# pymilvus.readthedoc     [ <=>                ]  21.82K  --.-KB/s    in 0s
#
# 2023-09-21 19:38:31 (152 MB/s) - ‘rtdocs/pymilvus.readthedocs.io/en/1.1/_modules/milvus/client/types.html’ saved [22341]
#
# --2023-09-21 19:38:31--  https://pymilvus.readthedocs.io/en/1.0/index.html
# Reusing existing connection to pymilvus.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/pymilvus.readthedocs.io/en/1.0/index.html’
#
# pymilvus.readthedoc     [ <=>                ]  10.59K  --.-KB/s    in 0s
#
# 2023-09-21 19:38:31 (2.53 GB/s) - ‘rtdocs/pymilvus.readthedocs.io/en/1.0/index.html’ saved [10845]
#
# --2023-09-21 19:38:31--  https://pymilvus.readthedocs.io/en/1.0/_modules/milvus/client/stub.html
# Reusing existing connection to pymilvus.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/pymilvus.readthedocs.io/en/1.0/_modules/milvus/client/stub.html’
#
# pymilvus.readthedoc     [ <=>                ] 112.04K  --.-KB/s    in 0.006s
#
# 2023-09-21 19:38:32 (17.9 MB/s) - ‘rtdocs/pymilvus.readthedocs.io/en/1.0/_modules/milvus/client/stub.html’ saved [114730]
#
# --2023-09-21 19:38:32--  https://pymilvus.readthedocs.io/en/1.0/_modules/milvus/client/types.html
# Reusing existing connection to pymilvus.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/pymilvus.readthedocs.io/en/1.0/_modules/milvus/client/types.html’
#
# pymilvus.readthedoc     [ <=>                ]  21.82K  --.-KB/s    in 0s
#
# 2023-09-21 19:38:32 (227 MB/s) - ‘rtdocs/pymilvus.readthedocs.io/en/1.0/_modules/milvus/client/types.html’ saved [22347]
#
# --2023-09-21 19:38:32--  https://pymilvus.readthedocs.io/en/1.1/_modules/index.html
# Reusing existing connection to pymilvus.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/pymilvus.readthedocs.io/en/1.1/_modules/index.html’
#
# pymilvus.readthedoc     [ <=>                ]   8.10K  --.-KB/s    in 0s
#
# 2023-09-21 19:38:32 (1.93 GB/s) - ‘rtdocs/pymilvus.readthedocs.io/en/1.1/_modules/index.html’ saved [8298]
#
# --2023-09-21 19:38:32--  https://pymilvus.readthedocs.io/en/1.0/_modules/index.html
# Reusing existing connection to pymilvus.readthedocs.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/pymilvus.readthedocs.io/en/1.0/_modules/index.html’
#
# pymilvus.readthedoc     [ <=>                ]   8.11K  --.-KB/s    in 0s
#
# 2023-09-21 19:38:32 (1.55 GB/s) - ‘rtdocs/pymilvus.readthedocs.io/en/1.0/_modules/index.html’ saved [8304]
#
# FINISHED --2023-09-21 19:38:32--
# Total wall clock time: 21s
# Downloaded: 58 files, 31M in 4.1s (7.46 MB/s)

# %%
# For now, manually move all .html files directly under rtdocs/
# !ls rtdocs/*
# Out:
# rtdocs/about.html      rtdocs/faq.html        rtdocs/param.html
# rtdocs/api.html        rtdocs/genindex.html   rtdocs/results.html
# rtdocs/changes.html    rtdocs/index.html      rtdocs/search.html
# rtdocs/contribute.html rtdocs/install.html    rtdocs/tutorial.html

# %%
# TODO:  Our docs HTML header says they are utf-8, but apparently not!
# Figure out how to download our ReadtheDocs as utf-8 encoded!

loader = ReadTheDocsLoader("rtdocs", features="html.parser")
docs = loader.load()

num_documents = len(docs)
print(f"loaded {num_documents} documents")
print(f"type: {type(docs)}, len: {len(docs)}, type: {type(docs[0])}")
docs[0]
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# /Users/christybergman/Documents/christy_github/ZillizDemos/milvus_onboarding/milvus_load_docs.ipynb Cell 6 line 5
#       <a href='vscode-notebook-cell:/Users/christybergman/Documents/christy_github/ZillizDemos/milvus_onboarding/milvus_load_docs.ipynb#X41sZmlsZQ%3D%3D?line=0'>1</a> # TODO:  Our docs HTML header says they are utf-8, but apparently not!
#       <a href='vscode-notebook-cell:/Users/christybergman/Documents/christy_github/ZillizDemos/milvus_onboarding/milvus_load_docs.ipynb#X41sZmlsZQ%3D%3D?line=1'>2</a> # Figure out how to download our ReadtheDocs as utf-8 encoded!
#       <a href='vscode-notebook-cell:/Users/christybergman/Documents/christy_github/ZillizDemos/milvus_onboarding/milvus_load_docs.ipynb#X41sZmlsZQ%3D%3D?line=3'>4</a> loader = ReadTheDocsLoader("rtdocs", features="html.parser")
# ----> <a href='vscode-notebook-cell:/Users/christybergman/Documents/christy_github/ZillizDemos/milvus_onboarding/milvus_load_docs.ipynb#X41sZmlsZQ%3D%3D?line=4'>5</a> docs = loader.load()
#       <a href='vscode-notebook-cell:/Users/christybergman/Documents/christy_github/ZillizDemos/milvus_onboarding/milvus_load_docs.ipynb#X41sZmlsZQ%3D%3D?line=6'>7</a> num_documents = len(docs)
#       <a href='vscode-notebook-cell:/Users/christybergman/Documents/christy_github/ZillizDemos/milvus_onboarding/milvus_load_docs.ipynb#X41sZmlsZQ%3D%3D?line=7'>8</a> print(f"loaded {num_documents} documents")
#
# File ~/mambaforge/envs/py310/lib/python3.10/site-packages/langchain/document_loaders/readthedocs.py:66, in ReadTheDocsLoader.load(self)
#      64     continue
#      65 with open(p, encoding=self.encoding, errors=self.errors) as f:
# ---> 66     text = self._clean_data(f.read())
#      67 metadata = {"source": str(p)}
#      68 docs.append(Document(page_content=text, metadata=metadata))
#
# File ~/mambaforge/envs/py310/lib/python3.10/codecs.py:322, in BufferedIncrementalDecoder.decode(self, input, final)
#     319 def decode(self, input, final=False):
#     320     # decode input (taking the buffer into account)
#     321     data = self.buffer + input
# --> 322     (result, consumed) = self._buffer_decode(data, self.errors, final)
#     323     # keep undecoded input until the next call
#     324     self.buffer = data[consumed:]
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xb8 in position 585: invalid start byte

# %%
# # Try a different docs page - this works fine!

# DOCS_PAGE="https://api.python.langchain.com/en/latest/"
# !echo $DOCS_PAGE

# # Specify encoding to handle non-unicode characters in documentation.
# !wget -r -A.html -P rtdocs2 --header="Accept-Charset: UTF-8" $DOCS_PAGE

loader = ReadTheDocsLoader("rtdocs2", features="html.parser")
docs = loader.load()

num_documents = len(docs)
print(f"loaded {num_documents} documents")
print(f"type: {type(docs)}, len: {len(docs)}, type: {type(docs[0])}")
docs[0]
# Out:
# loaded 34 documents
# type: <class 'list'>, len: 34, type: <class 'langchain.schema.document.Document'>
# Document(page_content='langchain_experimental API Reference¶\nlangchain_experimental.autonomous_agents¶\nClasses¶\nautonomous_agents.autogpt.agent.AutoGPT(...)\nAgent class for interacting with Auto-GPT.\nautonomous_agents.autogpt.memory.AutoGPTMemory\nMemory for AutoGPT.\nautonomous_agents.autogpt.output_parser.AutoGPTAction(...)\nAction returned by AutoGPTOutputParser.\nautonomous_agents.autogpt.output_parser.AutoGPTOutputParser\nOutput parser for AutoGPT.\nautonomous_agents.autogpt.output_parser.BaseAutoGPTOutputParser\nBase Output parser for AutoGPT.\nautonomous_agents.autogpt.prompt.AutoGPTPrompt\nPrompt for AutoGPT.\nautonomous_agents.autogpt.prompt_generator.PromptGenerator()\nA class for generating custom prompt strings.\nautonomous_agents.baby_agi.baby_agi.BabyAGI\nController model for the BabyAGI agent.\nautonomous_agents.baby_agi.task_creation.TaskCreationChain\nChain generating tasks.\nautonomous_agents.baby_agi.task_execution.TaskExecutionChain\nChain to execute tasks.\nautonomous_agents.baby_agi.task_prioritization.TaskPrioritizationChain\nChain to prioritize tasks.\nautonomous_agents.hugginggpt.hugginggpt.HuggingGPT(...)\nautonomous_agents.hugginggpt.repsonse_generator.ResponseGenerationChain\nChain to execute tasks.\nautonomous_agents.hugginggpt.repsonse_generator.ResponseGenerator(...)\nautonomous_agents.hugginggpt.task_executor.Task(...)\nautonomous_agents.hugginggpt.task_executor.TaskExecutor(plan)\nLoad tools to execute tasks.\nautonomous_agents.hugginggpt.task_planner.BasePlanner\nCreate a new model by parsing and validating input data from keyword arguments.\nautonomous_agents.hugginggpt.task_planner.Plan(steps)\nautonomous_agents.hugginggpt.task_planner.PlanningOutputParser\nCreate a new model by parsing and validating input data from keyword arguments.\nautonomous_agents.hugginggpt.task_planner.Step(...)\nautonomous_agents.hugginggpt.task_planner.TaskPlaningChain\nChain to execute tasks.\nautonomous_agents.hugginggpt.task_planner.TaskPlanner\nCreate a new model by parsing and validating input data from keyword arguments.\nFunctions¶\nautonomous_agents.autogpt.output_parser.preprocess_json_input(...)\nPreprocesses a string to be parsed as json.\nautonomous_agents.autogpt.prompt_generator.get_prompt(tools)\nGenerates a prompt string.\nautonomous_agents.hugginggpt.repsonse_generator.load_response_generator(llm)\nautonomous_agents.hugginggpt.task_planner.load_chat_planner(llm)\nlangchain_experimental.comprehend_moderation¶\nClasses¶\ncomprehend_moderation.amazon_comprehend_moderation.AmazonComprehendModerationChain\nA subclass of Chain, designed to apply moderation to LLMs.\ncomprehend_moderation.base_moderation.BaseModeration(client)\ncomprehend_moderation.base_moderation_callbacks.BaseModerationCallbackHandler()\ncomprehend_moderation.base_moderation_config.BaseModerationConfig\nCreate a new model by parsing and validating input data from keyword arguments.\ncomprehend_moderation.base_moderation_config.ModerationIntentConfig\nCreate a new model by parsing and validating input data from keyword arguments.\ncomprehend_moderation.base_moderation_config.ModerationPiiConfig\nCreate a new model by parsing and validating input data from keyword arguments.\ncomprehend_moderation.base_moderation_config.ModerationToxicityConfig\nCreate a new model by parsing and validating input data from keyword arguments.\ncomprehend_moderation.base_moderation_exceptions.ModerationIntentionError([...])\nException raised if Intention entities are detected.\ncomprehend_moderation.base_moderation_exceptions.ModerationPiiError([...])\nException raised if PII entities are detected.\ncomprehend_moderation.base_moderation_exceptions.ModerationToxicityError([...])\nException raised if Toxic entities are detected.\ncomprehend_moderation.intent.ComprehendIntent(client)\ncomprehend_moderation.pii.ComprehendPII(client)\ncomprehend_moderation.toxicity.ComprehendToxicity(client)\nlangchain_experimental.cpal¶\nClasses¶\ncpal.constants.Constant( ...

# %%
# Chunk the data using Langchain's RecursiveCharacterTextSplitter.
start_time = time.time()

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size = 500,
    chunk_overlap  = 50,
    length_function = len,
)

chunks = text_splitter.create_documents(
    [doc.page_content for doc in docs], 
    metadatas=[doc.metadata for doc in docs])

end_time = time.time()
print(f"chunking time: {end_time - start_time}")
# print(f"type: {type(chunks)}, len: {len(chunks)}, type: {type(chunks[0])}")
print(f"type: {type(chunks)}, len: {len(chunks)}") 

print()
print("Looking at a sample chunk...")
print(chunks[0].metadata)
print(chunks[0].page_content[:100])
# Out:
# chunking time: 0.011813163757324219
# type: <class 'list'>, len: 700
#
# Looking at a sample chunk...
# {'source': 'rtdocs2/api.python.langchain.com/en/latest/experimental_api_reference.html'}
# langchain_experimental API Reference¶
# langchain_experimental.autonomous_agents¶
# Classes¶
# autonomous_

# %%
# Clean up the metadata urls
for doc in chunks:
    new_url = doc.metadata["source"]
    new_url = new_url.replace("rtdocs2", "https:/")
    doc.metadata.update({"source": new_url})

print(chunks[0].metadata)
print(chunks[0].page_content[:500])
# Out:
# {'source': 'https://api.python.langchain.com/en/latest/experimental_api_reference.html'}
# langchain_experimental API Reference¶
# langchain_experimental.autonomous_agents¶
# Classes¶
# autonomous_agents.autogpt.agent.AutoGPT(...)
# Agent class for interacting with Auto-GPT.
# autonomous_agents.autogpt.memory.AutoGPTMemory
# Memory for AutoGPT.
# autonomous_agents.autogpt.output_parser.AutoGPTAction(...)
# Action returned by AutoGPTOutputParser.
# autonomous_agents.autogpt.output_parser.AutoGPTOutputParser
# Output parser for AutoGPT.
# autonomous_agents.autogpt.output_parser.BaseAutoGPTOutputParser

# %% [markdown]
# ## Chunk and embed data
#
# **First, choose an embedding model** <br>
# Most tutorials default to the OpenAI embedding model, which costs money.  You don't have to do that.
#
# In the code below, we will use an open source SentenceTransformer embedding model, hosted on HuggingFace.  [SentenceTransformers](https://www.sbert.net/) is a python package that can generate text and image embeddings, originating from Sentence-BERT.
#
# SentenceTransformers embeddings are called using the HuggingFaceEmbeddings integration. We have also added an alias for SentenceTransformerEmbeddings for users who are more familiar with directly using that package.

# %%
# Import torch.
#!pip install torch
import torch

# Initialize torch settings and get DEVICE.
torch.backends.cudnn.deterministic = True
RANDOM_SEED = 415
torch.manual_seed(RANDOM_SEED)
DEVICE = torch.device('cuda:3' if torch.cuda.is_available() else 'cpu')
print(f"device: {DEVICE}")
# Out:
# device: cpu

# %%
from langchain.embeddings import HuggingFaceEmbeddings

model_name = "BAAI/bge-base-en-v1.5"
model_kwargs = {"device": DEVICE}
model_kwargs = {'device': 'cpu'}
encode_kwargs = {'normalize_embeddings': True}

hf = HuggingFaceEmbeddings(
    model_name=model_name,
    model_kwargs=model_kwargs,
    encode_kwargs=encode_kwargs
)
type(hf)
# type: langchain.embeddings.huggingface.HuggingFaceEmbeddings
# Out:
# langchain.embeddings.huggingface.HuggingFaceEmbeddings

# %%
# TODO:  How to inspect the embedding model parameters?
# In this cell, I'll import directly and inspect.

# Import HuggingFace and SentenceTransformers.
#!pip install transformers sentence-transformers
from sentence_transformers import SentenceTransformer

# load the retriever model from huggingface model hub
model_name = "BAAI/bge-base-en-v1.5"
# model_name = "thenlper/gte-large"
# model_name = "intfloat/e5-base-v2"
retriever = SentenceTransformer(model_name, device=DEVICE)
print(type(retriever))
print(retriever)

# Define a query for estimation purposes.
query = 'Which index does Langchain Milvus default to?'
QUERY_LENGTH = len(query)
TOKENIZER_EOS = 4 # HuggingFace default is 4 bytes

# Save params for later.
max_seq_length = retriever.get_max_seq_length() #128
CHUNK_SIZE = max_seq_length - QUERY_LENGTH - 2*TOKENIZER_EOS
chunk_overlap = np.round(CHUNK_SIZE * 0.10, 0) #19
EMBEDDING_LENGTH = retriever.get_sentence_embedding_dimension() #384
print(f"embedding vector length: {EMBEDDING_LENGTH}, max_seq_length: {max_seq_length}")
print(f"CHUNK_SIZE: {CHUNK_SIZE}, chunk_overlap: {chunk_overlap}")

# model_name = "BAAI/bge-base-en-v1.5"
# embedding vector length: 768, chunk size: 512, chunk_overlap: 51.0

# model_name = "thenlper/gte-large"
# embedding vector length: 1024, chunk size: 512, chunk_overlap: 51.0
# Out:
# <class 'sentence_transformers.SentenceTransformer.SentenceTransformer'>
# SentenceTransformer(
#   (0): Transformer({'max_seq_length': 512, 'do_lower_case': True}) with Transformer model: BertModel
#   (1): Pooling({'word_embedding_dimension': 768, 'pooling_mode_cls_token': True, 'pooling_mode_mean_tokens': False, 'pooling_mode_max_tokens': False, 'pooling_mode_mean_sqrt_len_tokens': False})
# )
# embedding vector length: 768, max_seq_length: 512
# CHUNK_SIZE: 459, chunk_overlap: 46.0

# %%
# Define a query for estimation purposes.
query = 'Which index does Langchain Milvus default to?'
QUERY_LENGTH = len(query)
print(QUERY_LENGTH)
# Out:
# 45

# %% [markdown]
# ## Save embeddings in a vector store.

# %%
# Upload data to FAISS vectorstore.
# !python -m pip install faiss-cpu
from langchain.vectorstores import FAISS

print("Embed and create vector index")
start_time = time.time()
vectorstore = FAISS.from_documents(chunks, embedding=hf)

# Persist the vector store.
vectorstore.save_local("faiss_index")

end_time = time.time()
print(f"FAISS insert time: {end_time - start_time}")
print(f"type: {type(vectorstore)}")
vectorstore
# Out:
# Embed and create vector index
# FAISS insert time: 60.16475701332092
# type: <class 'langchain.vectorstores.faiss.FAISS'>

# %% [markdown]
# ### Now try Milvus
#
# [In a previous notebook](milvus_connect.ipynb), I showed how to connect to milvus and invoke Python APIs from scratch.
#
# The code below uses the [Langchain Milvus](https://api.python.langchain.com/en/latest/vectorstores/langchain.vectorstores.milvus.Milvus.html) adapter.  Defaults are:
#
# - embedding_function (Embeddings) – Function used to embed the text.
# - collection_name (str) – Which Milvus collection to use. Defaults to “LangChainCollection”.
# - connection_args (Optional[dict[str, any]]) – The connection args used for this class comes in the form of a dict.
# - consistency_level (str) – The consistency level to use for a collection. Defaults to “Session”.
# - index_params (Optional[dict]) – Which index params to use. Defaults to HNSW/AUTOINDEX depending on service.
# - search_params (Optional[dict]) – Which search params to use. Defaults to default of index.
# - drop_old (Optional[bool]) – Whether to drop the current collection. Defaults to False.
# - primary_field (str) – Name of the primary key field. Defaults to “pk”.
# - text_field (str) – Name of the text field. Defaults to “text”.
# - vector_field (str) – Name of the vector field. Defaults to “vector”.

# %%
# Upload data to Milvus vectorstore.

#!pip install pymilvus
from langchain.vectorstores import Milvus
MILVUS_PORT = 19530
MILVUS_HOST = "127.0.0.1"

print("Embed and create vector index")
start_time = time.time()
vector_store = Milvus.from_documents(
    chunks,
    embedding=hf,
    connection_args={"host": MILVUS_HOST, "port": MILVUS_PORT},
)

end_time = time.time()
print(f"vector database insert time: {end_time - start_time}")
print(f"type: {type(vector_store)}")
vector_store

# Inserting into Milvus, a full-fledged database is just as fast as FAISS!
# Out:
# Embed and create vector index
# vector database insert time: 59.87231993675232
# type: <class 'langchain.vectorstores.milvus.Milvus'>

# %% [markdown]
# ## Query the vectors
#
# This is the "Retrieval" part of "RAG" (Retrieval Augmented Generator).

# %%
print(query)
# Out:
# Which index does Langchain Milvus default to?

# %%
# RETRIEVAL USING FAISS

# Always use the exact same LLM for both doc and query embeddings.
query_embedding = HuggingFaceEmbeddings(model_name=model_name)

db = FAISS.load_local("faiss_index", query_embedding)
documents = db.similarity_search(query=query, k=1)
print(f"source: {docs[0].metadata}")
print([doc.page_content for doc in documents])
# Out:
# source: {'source': 'https://api.python.langchain.com/en/latest/api_reference.html'}
# ['retrievers.self_query.milvus.MilvusTranslator()\nTranslate Milvus internal query language elements to valid filters.\nretrievers.self_query.myscale.MyScaleTranslator([...])\nTranslate MyScale internal query language elements to valid filters.\nretrievers.self_query.pinecone.PineconeTranslator()\nTranslate Pinecone internal query language elements to valid filters.\nretrievers.self_query.qdrant.QdrantTranslator(...)\nTranslate Qdrant internal query language elements to valid filters.']

# %%
# RETRIEVAL USING MILVUS
docs = vector_store.similarity_search(query)
print(f"source: {docs[0].metadata}")
print([doc.page_content for doc in documents])

# Retrieval using Milvus takes 0.2s vs 1.2s for FAISS !!
# Out:
# source: {'source': 'https://api.python.langchain.com/en/latest/api_reference.html'}
# ['retrievers.self_query.milvus.MilvusTranslator()\nTranslate Milvus internal query language elements to valid filters.\nretrievers.self_query.myscale.MyScaleTranslator([...])\nTranslate MyScale internal query language elements to valid filters.\nretrievers.self_query.pinecone.PineconeTranslator()\nTranslate Pinecone internal query language elements to valid filters.\nretrievers.self_query.qdrant.QdrantTranslator(...)\nTranslate Qdrant internal query language elements to valid filters.']

# %% [markdown]
# ## Generate the chat answer using retrieved texts.
#
# This is the "Generator" part of "RAG" (Retrieval Augmented Generator).

# %%
from langchain.chains import RetrievalQA

# %%
# Props to Sebastian Raschka for this handy watermark.
# !pip install watermark

# %load_ext watermark
# %watermark -a 'Christy Bergman' -v -p torch,transformers,pymilvus,langchain --conda
# Out:
# The watermark extension is already loaded. To reload it, use:
#   %reload_ext watermark
# Author: Christy Bergman
#
# Python implementation: CPython
# Python version       : 3.10.12
# IPython version      : 8.15.0
#
# torch       : 2.0.1
# transformers: 4.33.2
# pymilvus    : 2.3.0
# langchain   : 0.0.292
#
# conda environment: py310
